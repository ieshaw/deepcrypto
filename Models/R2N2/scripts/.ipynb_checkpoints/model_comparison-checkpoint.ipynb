# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
loss_df = pd.read_csv('/Users/ianshaw/Downloads/GitHub/deepcrypto/Models/R2N2/model_compare/all_loss.csv')

# %%
loss_df
# Out:
#              Model   Opt  Hidden_Size  Learning      Loss
# 0   Adam_15_97_100  Adam           15        97  0.014070
# 1   Adam_19_81_100  Adam           19        81  0.010528
# 2   Adam_44_46_100  Adam           44        46  0.010026
# 3   Adam_55_89_100  Adam           55        89  0.008144
# 4   Adam_69_27_100  Adam           69        27  0.005202
# 5   Adam_69_53_100  Adam           69        53  0.001844
# 6   Adam_73_33_100  Adam           73        33  0.007494
# 7   Adam_80_34_100  Adam           80        34  0.007527
# 8   Adam_81_39_100  Adam           81        39  0.006215
# 9   Adam_85_70_100  Adam           85        70  0.003884
# 10  Adam_87_99_100  Adam           87        99  0.007688
# 11  Adam_89_62_100  Adam           89        62  0.004026
# 12  Adam_89_81_100  Adam           89        81  0.003706
# 13  Adam_98_12_100  Adam           98        12  0.002012
# 14   SGD_11_93_100   SGD           11        93  0.000313
# 15   SGD_21_90_100   SGD           21        90  0.000310
# 16   SGD_23_59_100   SGD           23        59  0.000288
# 17   SGD_26_62_100   SGD           26        62  0.000289
# 18   SGD_30_46_100   SGD           30        46  0.000279
# 19   SGD_33_43_100   SGD           33        43  0.000277
# 20   SGD_39_28_100   SGD           39        28  0.000267
# 21   SGD_44_13_100   SGD           44        13  0.000259
# 22   SGD_45_99_100   SGD           45        99  0.000316
# 23   SGD_47_54_100   SGD           47        54  0.000283
# 24   SGD_47_79_100   SGD           47        79  0.000301
# 25   SGD_57_81_100   SGD           57        81  0.000301
# 26   SGD_58_35_100   SGD           58        35  0.000271
# 27   SGD_66_56_100   SGD           66        56  0.000284
# 28   SGD_67_38_100   SGD           67        38  0.000273
# 29   SGD_72_24_100   SGD           72        24  0.000264
# 30   SGD_77_71_100   SGD           77        71  0.000294
# 31    SGD_7_64_100   SGD            7        64  0.000292
# 32   SGD_80_22_100   SGD           80        22  0.000263
# 33   SGD_96_32_100   SGD           96        32  0.000268
# 34   SGD_97_46_100   SGD           97        46  0.000276
# 35   SGD_98_16_100   SGD           98        16  0.000260
# 36    SGD_9_38_100   SGD            9        38  0.000275
# 37    SGD_9_52_100   SGD            9        52  0.000284
# 38    SGD_9_53_100   SGD            9        53  0.000285
# 39  SGDM_10_69_100  SGDM           10        69  0.000660
# 40  SGDM_14_73_100  SGDM           14        73  0.000674
# 41  SGDM_18_66_100  SGDM           18        66  0.000623
# 42  SGDM_25_84_100  SGDM           25        84  0.000761
# 43  SGDM_48_83_100  SGDM           48        83  0.000736
# 44  SGDM_49_78_100  SGDM           49        78  0.000723
# 45  SGDM_62_93_100  SGDM           62        93  0.000838
# 46  SGDM_63_30_100  SGDM           63        30  0.000422
# 47  SGDM_81_95_100  SGDM           81        95  0.000872
# 48  SGDM_88_36_100  SGDM           88        36  0.000460
# 49  SGDM_99_73_100  SGDM           99        73  0.000699

# %%
#Plot hidden layers vs. loss
loss_df = loss_df.loc[loss_df['Loss'] < 0.0005]
loss_df = loss_df.sort('Hidden_Size')
x_val = 'Hidden_Size'
plt.semilogy(loss_df[x_val].values, loss_df['Loss'].values)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()

# %%
#Plot optimizer vs. loss
opt_df = loss_df.loc[loss_df['Opt'].isin(['SGDM'])]
x_val = 'Hidden_Size'
plt.semilogy(opt_df[x_val].values, opt_df['Loss'].values, label = 'SGDM')
opt_df = loss_df.loc[loss_df['Opt'].isin(['SGD'])]
plt.semilogy(opt_df[x_val].values, opt_df['Loss'].values, label = 'SGD')
opt_df = loss_df.loc[loss_df['Opt'].isin(['Adam'])]
plt.semilogy(opt_df[x_val].values, opt_df['Loss'].values, label = 'Adam')
plt.legend()
plt.show()

# %%
#Plot Learning (learning rate * 10^3) vs. loss
x_val = 'Learning'
loss_df = loss_df.sort(x_val)
plt.semilogy(loss_df[x_val].values, loss_df['Loss'].values)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()
